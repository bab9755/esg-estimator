# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tickers = ['NVDA', 'MSFT', 'GOOGL', 'GOOG', 'AMZN', 'META', 'TSLA', 'BRK-B', 
 'XOM', 'COST', 'JNJ', 'CRM', 'CVX', 'NOW', 'AMD', 'DIS', 'ABT', 
 'ADBE', 'ISRG', 'INTU', 'DHR', 'SPGI', 'ANET', 'PGR']

df = yf.download(tickers, period="5y")
# Out:
# [*********************100%***********************]  24 of 24 completed

# %%
df.head()
# Out:
# Price           Close                                               \
# Ticker            ABT        ADBE        AMD       AMZN       ANET
# Date
# 2019-12-24  79.992393  329.640015  46.540001  89.460503  12.790000
# 2019-12-26  79.992393  331.200012  46.630001  93.438499  12.850625
# 2019-12-27  80.102379  330.790009  46.180000  93.489998  12.776875
# 2019-12-30  79.552467  328.339996  45.520000  92.344498  12.695625
# 2019-12-31  79.607452  329.809998  45.860001  92.391998  12.712500
#
# Price                                                                  ...  \
# Ticker           BRK-B        COST         CRM        CVX         DHR  ...
# Date                                                                   ...
# 2019-12-24  225.470001  270.406342  162.343246  97.335411  133.278137  ...
# 2019-12-26  226.449997  271.784851  163.596252  97.545708  132.973618  ...
# 2019-12-27  226.139999  270.295959  164.063644  97.303055  133.025848  ...
# 2019-12-30  225.759995  271.242584  161.537750  96.939072  132.991043  ...
# 2019-12-31  226.500000  270.121429  161.736633  97.472923  133.547928  ...
#
# Price        Volume                                                            \
# Ticker         ISRG      JNJ      META      MSFT      NOW       NVDA      PGR
# Date
# 2019-12-24   838800  4238900   6046300   8989200   305700  138864000   778200
# 2019-12-26   994500  3019300   9350700  14520600   946000  182852000  1612900
# 2019-12-27  1287300  3432700  10284200  18412800   997600  254644000  1570600
# 2019-12-30  1133100  2923300  10524300  16348400  1406200  258056000  1298600
# 2019-12-31  1344300  4435000   8953500  18369400   970400  231004000  1724500
#
# Price
# Ticker        SPGI       TSLA       XOM
# Date
# 2019-12-24  363000  120820500   3979400
# 2019-12-26  450300  159508500   8840200
# 2019-12-27  688800  149185500  10516100
# 2019-12-30  539000  188796000  12689400
# 2019-12-31  638900  154285500  13151800
#
# [5 rows x 120 columns]

# %%
print(df.columns)
close_prices = df['Close']
close_prices
# Out:
# MultiIndex([( 'Close',   'ABT'),
#             ( 'Close',  'ADBE'),
#             ( 'Close',   'AMD'),
#             ( 'Close',  'AMZN'),
#             ( 'Close',  'ANET'),
#             ( 'Close', 'BRK-B'),
#             ( 'Close',  'COST'),
#             ( 'Close',   'CRM'),
#             ( 'Close',   'CVX'),
#             ( 'Close',   'DHR'),
#             ...
#             ('Volume',  'ISRG'),
#             ('Volume',   'JNJ'),
#             ('Volume',  'META'),
#             ('Volume',  'MSFT'),
#             ('Volume',   'NOW'),
#             ('Volume',  'NVDA'),
#             ('Volume',   'PGR'),
#             ('Volume',  'SPGI'),
#             ('Volume',  'TSLA'),
#             ('Volume',   'XOM')],
#            names=['Price', 'Ticker'], length=120)
# Ticker             ABT        ADBE         AMD        AMZN        ANET  \
# Date
# 2019-12-24   79.992393  329.640015   46.540001   89.460503   12.790000
# 2019-12-26   79.992393  331.200012   46.630001   93.438499   12.850625
